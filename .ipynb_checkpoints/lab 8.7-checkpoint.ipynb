# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.metrics import pairwise_distances_argmin_min

from sklearn import datasets
from sklearn.cluster import KMeans

# %% [markdown]
# The experiments you did with the Spotify API and the Billboard web scraping will allow you to create a pipeline such that when the user enters a song, you:
#
# -Check whether or not the song is in the Billboard Hot 200.
#
# -Collect the audio features from the Spotify API.
#
# After that, you want to send the Spotify audio features of the submitted song to the clustering model, which should return a cluster number.

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="f4f782b3eaa04cd18833d9d54311716a",
                                                           client_secret="0395f00a0f5942fdb4a7073e7635d350"))

# %%
p2= sp.user_playlist_tracks("spotify", "37i9dQZF1DX1WhyP6stXXl")
p2
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1WhyP6stXXl/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-06-16T22:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5BmVxdltuGK9CqZVaiUEKy'},
#        'href': 'https://api.spotify.com/v1/artists/5BmVxdltuGK9CqZVaiUEKy',
#        'id': '5BmVxdltuGK9CqZVaiUEKy',
#        'name': 'clide',
#        'type': 'artist',
#        'uri': 'spotify:artist:5BmVxdltuGK9CqZVaiUEKy'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AM',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BD',
#       'BE',
#       'BG',
# ...

# %%
track_ids= [] 
for i in range(0,len(p2['items'])):
    track_ids.append(p2['items'][i]['track']['id'])
#track_ids

# %%
features = sp.audio_features(track_ids)
df = pd.DataFrame(features)
#df

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
p2['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
playlists = ["45cmyHFMiW2YCjUrNioaRR", 
             "37i9dQZF1DX1WhyP6stXXl",
             "37i9dQZF1DXbX3zSzB4MO0",
             "37i9dQZF1DX8AliSIsGeKd",
             "37i9dQZF1DWVWiyE9VDkCO",
             "37i9dQZF1DX5cO1uP1XC1g",
             "37i9dQZF1DWZd79rJ6a7lp",
             "37i9dQZF1DX3Ogo9pFvBkY",
             "5i0m2whLHnXlytw3JDARca",
             "1aERvtdY3DydPHAvPjsCTE"]

# %%
df_final = pd.DataFrame()



for playlist in playlists:
    
    p = sp.user_playlist_tracks("spotify", playlist)
    track_ids= [] 
    for i in range(0,len(p['items'])):
        if p['items'][i]['track']['id']: # <- shortcut of if x == True, ignores the "none" id
            track_ids.append(p['items'][i]['track']['id'])
            
    tracks = p ['items']
    while p['next']:
        p = sp.next(p)
        tracks.extend(p['items'])

    song_names =[]
    song_artist=[]
    for i in range(len(tracks)):
        song_names.append(tracks[i]['track']['name'])
        song_artist.append(tracks[i]["track"]["artists"][0]["name"])
    df_songname = pd.DataFrame(song_names)
    df_artist = pd.DataFrame(song_artist)
    
    features = sp.audio_features(track_ids)
    df = pd.DataFrame(features)
    
    df = df[['danceability', 'energy','key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'id']]
             
    df_final= pd.concat([df, df_songname, df_artist], axis=1, join='inner')

#len(track_ids)

# %%
df_final
# Out:
#     danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.4650   0.798    0    -8.449       0.0429        0.0986
# 1         0.4490   0.978    2    -7.694       0.0651        0.5910
# 2         0.1360   0.462    2   -10.982       0.0367        0.0945
# 3         0.4030   0.591    1    -8.126       0.0514        0.5110
# 4         0.3820   0.814    7    -8.646       0.0461        0.1450
# ..           ...     ...  ...       ...          ...           ...
# 92        0.7280   0.762    1    -8.097       0.0914        0.0562
# 93        0.3600   0.918    1    -8.996       0.1090        0.0220
# 94        0.1700   0.395    0   -17.928       0.0462        0.0742
# 95        0.0877   0.361    0   -13.231       0.0399        0.4300
# 96        0.1190   0.125    9   -20.239       0.0343        0.5570
#
#     instrumentalness  liveness  valence                      id  \
# 0              0.864    0.1670   0.3640  4o0sJFXHckKlBhhynZsSIg
# ...

# %%
df_final.columns = ['danceability', 'energy','key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'id', 'title', 'artist']
df_final.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.465   0.798    0    -8.449       0.0429        0.0986
# 1         0.449   0.978    2    -7.694       0.0651        0.5910
# 2         0.136   0.462    2   -10.982       0.0367        0.0945
# 3         0.403   0.591    1    -8.126       0.0514        0.5110
# 4         0.382   0.814    7    -8.646       0.0461        0.1450
#
#    instrumentalness  liveness  valence                      id  \
# 0             0.864     0.167    0.364  4o0sJFXHckKlBhhynZsSIg
# 1             0.955     0.192    0.514  5DXOWLHduYdWEzdjq6XzpN
# 2             0.936     0.119    0.112  2jn89xTHIVsy167uOmAewt
# 3             0.896     0.108    0.192  4JtvyWkWQTPVcroZf8JJkp
# 4             0.884     0.161    0.178  1No2I2TNhCXDNovL5O7ang
#
#                   title            artist
# 0             El Dorado  Thomas Bergersen
# 1  All the Kings Horses  Thomas Bergersen
# 2            Blackheart  Thomas Bergersen
# ...

# %%
df_artist
# Out:
#                    0
# 0   Thomas Bergersen
# 1   Thomas Bergersen
# 2   Thomas Bergersen
# 3   Thomas Bergersen
# 4   Thomas Bergersen
# ..               ...
# 93        Éric Serra
# 94  Thomas Bergersen
# 95   Steve Jablonsky
# 96   Clinton Shorter
# 97   Guillaume David
#
# [98 rows x 1 columns]

# %%
# select the features that we need
x = df[['danceability', 'energy','key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']]

# standarize the data
scaler = StandardScaler()
x_prep = scaler.fit_transform(x)

# train and predict
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(x_prep)
clusters = kmeans.predict(x_prep)

#create new dataframe with title, artist and cluster assigned
scaled_df = pd.DataFrame(x_prep, columns=x.columns)
scaled_df['title'] = df_final['title']
scaled_df['artist'] = df_final['artist']
scaled_df['cluster'] = clusters
scaled_df
# Out:
#     danceability    energy       key  loudness  speechiness  acousticness  \
# 0       1.029552  1.250802 -1.351833  0.695681    -0.064186     -1.160490
# 1       0.926599  1.975583 -0.769043  0.866746     1.173221      0.351060
# 2      -1.087423 -0.102121 -0.769043  0.121767    -0.409768     -1.173076
# 3       0.630608  0.417305 -1.060438  0.768865     0.409596      0.105479
# 4       0.495482  1.315227  0.687933  0.651046     0.114179     -1.018053
# ..           ...       ...       ...       ...          ...           ...
# 92      2.721846  1.105846 -1.060438  0.775436     2.639158     -1.290648
# 93      0.353922  1.733989 -1.060438  0.571745     3.620165     -1.395633
# 94     -0.868648 -0.371900 -1.351833 -1.452024     0.119753     -1.235392
# 95     -1.398214 -0.508803 -1.351833 -0.387801    -0.231403     -0.143171
# 96     -1.196811 -1.459071  1.270723 -1.975639    -0.543542      0.246688
#
#     instrumentalness  liveness   valence                 title  \
# ...

# %%
scaled_df.groupby(['cluster', 'artist'], as_index=False).count().sort_values(['cluster', 'key'], ascending=[True, False])[['artist', 'cluster', 'key']].reset_index(drop=True)
# Out:
#                    artist  cluster  key
# 0        Thomas Bergersen        0   11
# 1           Paul Dinletir        0    5
# 2   Falcom Sound Team jdk        0    3
# 3               Immediate        0    3
# 4     Two Steps from Hell        0    3
# 5          E.S. Posthumus        0    1
# 6             Eric Neveux        0    1
# 7                Eurielle        0    1
# 8      Future World Music        0    1
# 9          John A. Graves        0    1
# 10              Kevin Rix        0    1
# 11      Marshall Crutcher        0    1
# 12       TADAYOSHI MAKINO        0    1
# 13              X-Ray Dog        0    1
# 14             Éric Serra        0    1
# 15          Paul Dinletir        1    8
# 16  Falcom Sound Team jdk        1    7
# 17          John Williams        1    5
# 18       Thomas Bergersen        1    4
# 19              Immediate        1    3
# 20         Richard Beddow        1    3
# 21     Future World Music        1    2
# ...

# %%
#PelleK - Ah, My Romantic Road
#Kaiserbase - Berlin - Du bist so wunderbar 2012
#Skillet - Monster

song_name = input('Choose a song: ')
results = sp.search(q=f'track:{song_name}', limit=1)
track_id = results['tracks']['items'][0]['id']
audio_features = sp.audio_features(track_id)

df_ = pd.DataFrame(audio_features)
new_features = df_[x.columns]

scaled_x = scaler.transform(new_features)
cluster = kmeans.predict(scaled_x)

filtered_df = scaled_df[scaled_df['cluster'] == cluster[0]][x.columns]
closest, _ = pairwise_distances_argmin_min(scaled_x, filtered_df)
scaled_df.loc[closest[0]]['title'], scaled_df.loc[closest[0]]['artist']

# %%
scaled_x
# Out:
# array([[ 2.15560295,  1.89102495,  0.97932789,  2.08073527,  1.67487212,
#         -1.3308614 , -2.87083162, -0.68569143,  2.82823089]])

# %%
scaled_df[scaled_df.title == 'Children of the Omnissiah']
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, speechiness, acousticness, instrumentalness, liveness, valence, title, artist, cluster]
# Index: []

# %%
# put everything inside a function
def recommend_song():
    # get song id
    song_name = input('Choose a song: ')
    results = sp.search(q=f'track:{song_name}', limit=1)
    track_id = results['tracks']['items'][0]['id']
    # get song features with the obtained id
    audio_features = sp.audio_features(track_id)
    # create dataframe
    df_ = pd.DataFrame(audio_features)
    new_features = df_[x.columns]
    # scale features
    scaled_x = scaler.transform(new_features)
    # predict cluster
    cluster = kmeans.predict(scaled_x)
    # filter dataset to predicted cluster
    filtered_df = scaled_df[scaled_df['cluster'] == cluster[0]][x.columns]
    # get closest song from filtered dataset
    closest, _ = pairwise_distances_argmin_min(scaled_x, filtered_df)
    # return it in a readable way
    print('\n [RECOMMENDED SONG]')
    return ' - '.join([scaled_df.loc[closest]['title'].values[0], scaled_df.loc[closest]['artist'].values[0]])

# %%
recommend_song()
# Out:
# Choose a song: Ah, My Romantic Road
#
#  [RECOMMENDED SONG]
# 'Invincible - Two Steps from Hell'

# %% [markdown]
# ### K-Mean

# %%
X = pd.DataFrame(df[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']])
y = pd.Series(df["key"])

X.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.465   0.798    -8.449       0.0429        0.0986
# 1         0.449   0.978    -7.694       0.0651        0.5910
# 2         0.136   0.462   -10.982       0.0367        0.0945
# 3         0.403   0.591    -8.126       0.0514        0.5110
# 4         0.382   0.814    -8.646       0.0461        0.1450
#
#    instrumentalness  liveness  valence
# 0             0.864     0.167    0.364
# 1             0.955     0.192    0.514
# 2             0.936     0.119    0.112
# 3             0.896     0.108    0.192
# 4             0.884     0.161    0.178

# %%
y.unique()
# Out:
# array([ 0,  2,  1,  7,  3,  9,  5, 10,  8, 11,  4], dtype=int64)

# %%
X_prep = StandardScaler().fit_transform(X)

pd.DataFrame(X_prep).head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.029552  1.250802  0.695681 -0.064186 -1.160490  0.370912  0.355369
# 1  0.926599  1.975583  0.866746  1.173221  0.351060  0.712346  0.650789
# 2 -1.087423 -0.102121  0.121767 -0.409768 -1.173076  0.641058 -0.211838
# 3  0.630608  0.417305  0.768865  0.409596  0.105479  0.490977 -0.341822
# 4  0.495482  1.315227  0.651046  0.114179 -1.018053  0.445953  0.284468
#
#           7
# 0  0.967117
# 1  1.818236
# 2 -0.462763
# 3 -0.008833
# 4 -0.088271

# %%
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([ 9,  1,  8,  3,  9,  9,  9,  2,  6,  8,  6,  9,  1,  1,  9,  4,  5,
#         4,  4,  4,  8,  8,  8,  7,  8,  7,  8,  5,  8,  6,  2,  2, 10,  2,
#         2,  7, 10,  7,  0,  2, 10, 10,  0,  7,  2, 10, 10,  8,  7,  8,  7,
#         6,  1,  3,  2,  3,  2,  8,  5,  9,  2,  8,  5,  3,  1,  4,  0,  3,
#         8,  7,  9,  8,  9,  2,  8,  5,  7,  2,  2,  2,  7,  0,  2,  8,  6,
#         3,  8,  4,  3,  2,  7,  6,  1,  6,  8,  4, 10])

# %%
kmeans = KMeans(n_clusters=11, random_state=42) #number of clusters usually unknown
kmeans.fit(X_prep) # fit for training , in unsupervised no y_train
# Out:
# KMeans(n_clusters=11, random_state=42)

# %%
np.array(y)
# Out:
# array([ 0,  2,  2,  1,  7,  0,  7,  3,  9,  5, 10,  2,  5,  0,  2,  9,  7,
#         8,  7,  7,  8,  2,  1,  0, 10,  5,  0,  2, 10,  0,  3,  2,  2, 10,
#         7, 11,  8,  7, 10,  7,  9,  2,  2,  9,  9,  9,  9, 10,  7,  5,  0,
#         2,  5,  8,  2,  2,  3,  2,  0,  5,  5,  5,  5,  4,  5,  2,  9,  2,
#         5,  4,  0,  1,  7,  0,  0,  8,  5,  2,  0,  4, 10,  5,  4,  9,  0,
#         2,  9, 11,  2,  4,  7,  5,  1,  1,  0,  0,  9], dtype=int64)

# %%
print(classification_report(y, clusters))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.17      0.20      0.18         5
#            2       0.19      0.16      0.17        19
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         5
#            5       0.20      0.07      0.11        14
#            6       0.00      0.00      0.00         0
#            7       0.27      0.27      0.27        11
#            8       0.06      0.20      0.09         5
#            9       0.00      0.00      0.00        11
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00         2
#
#     accuracy                           0.09        97
#    macro avg       0.07      0.08      0.07        97
# weighted avg       0.11      0.09      0.09        97
# ...

# %%
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0      4
# 1      6
# 2     16
# 3      7
# 4      7
# 5      5
# 6      7
# 7     11
# 8     18
# 9      9
# 10     7
# dtype: int64

# %%
X_df = pd.DataFrame(X)
X_df["cluster"] = clusters
X_df.head()

X_df['cluster'] = X_df['cluster'].apply(lambda x: 0 if x == 1 else 1 if x == 2 else 2)
X_df
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0         0.4650   0.798    -8.449       0.0429        0.0986
# 1         0.4490   0.978    -7.694       0.0651        0.5910
# 2         0.1360   0.462   -10.982       0.0367        0.0945
# 3         0.4030   0.591    -8.126       0.0514        0.5110
# 4         0.3820   0.814    -8.646       0.0461        0.1450
# ..           ...     ...       ...          ...           ...
# 92        0.7280   0.762    -8.097       0.0914        0.0562
# 93        0.3600   0.918    -8.996       0.1090        0.0220
# 94        0.1700   0.395   -17.928       0.0462        0.0742
# 95        0.0877   0.361   -13.231       0.0399        0.4300
# 96        0.1190   0.125   -20.239       0.0343        0.5570
#
#     instrumentalness  liveness  valence  cluster
# 0              0.864    0.1670   0.3640        2
# 1              0.955    0.1920   0.5140        0
# 2              0.936    0.1190   0.1120        2
# ...

# %%
kmeans.inertia_
# Out:
# 212.6986631756867

# %%
X#_df.loc[0]
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0         0.4650   0.798    -8.449       0.0429        0.0986
# 1         0.4490   0.978    -7.694       0.0651        0.5910
# 2         0.1360   0.462   -10.982       0.0367        0.0945
# 3         0.4030   0.591    -8.126       0.0514        0.5110
# 4         0.3820   0.814    -8.646       0.0461        0.1450
# ..           ...     ...       ...          ...           ...
# 92        0.7280   0.762    -8.097       0.0914        0.0562
# 93        0.3600   0.918    -8.996       0.1090        0.0220
# 94        0.1700   0.395   -17.928       0.0462        0.0742
# 95        0.0877   0.361   -13.231       0.0399        0.4300
# 96        0.1190   0.125   -20.239       0.0343        0.5570
#
#     instrumentalness  liveness  valence  cluster
# 0              0.864    0.1670   0.3640        2
# 1              0.955    0.1920   0.5140        0
# 2              0.936    0.1190   0.1120        2
# ...

# %%
K = range(2, 20)

inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

inertia
# Out:
# [571.0751297260643,
#  497.95106811796455,
#  438.34214616859015,
#  378.2528827364849,
#  333.7939605323052,
#  296.2926725211376,
#  271.1591409813309,
#  251.0527231266617,
#  239.29848411524716,
#  211.59889642392164,
#  198.89786739766316,
#  190.7153578515035,
#  170.80776525553915,
#  164.24475904736462,
#  158.69358000019446,
#  153.7942131691935,
#  142.65945405012604,
#  136.8789866721919]

# %%
import matplotlib.pyplot as plt ### ELBOW, the inflexion normally is the best option

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %% [markdown]
# ### Silhouette Score

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)

silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %%
print(classification_report(y, X_df['cluster']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.07      0.10        15
#            1       0.00      0.00      0.00         5
#            2       0.20      0.79      0.32        19
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         5
#            5       0.00      0.00      0.00        14
#            7       0.00      0.00      0.00        11
#            8       0.00      0.00      0.00         5
#            9       0.00      0.00      0.00        11
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00         2
#
#     accuracy                           0.16        97
#    macro avg       0.03      0.08      0.04        97
# weighted avg       0.06      0.16      0.08        97
# ...

# %% [markdown]
# ### Visualizing Results

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Transform the data into 2D so we can see
pca = PCA(2) 
X_2D = pca.fit_transform(X_prep)
#X_2D

# %%
kmeans = KMeans(n_clusters=11, random_state=42)
kmeans.fit(X_2D)
# Out:
# KMeans(n_clusters=11, random_state=42)

# %%
clusters = kmeans.predict(X_2D)
clusters
# Out:
# array([ 4,  4,  8,  5,  5,  5,  4,  9, 10,  8,  2,  4,  4,  4,  5,  1,  6,
#         7,  7,  1,  5,  9,  3,  3,  3,  8,  8,  1,  9,  2,  3,  0,  0,  3,
#         0,  8,  0,  1,  1,  0,  0,  0,  1,  3,  3,  0,  0,  8,  8,  5,  9,
#        10,  4,  2,  3,  5,  3,  8,  5,  4,  3,  8,  1,  5,  4,  7,  1,  2,
#         8,  3,  5,  3,  6,  8,  9,  6,  5,  3,  9,  9,  3,  1,  9,  9,  5,
#         2,  3,  7,  5,  9,  8, 10,  4, 10,  3,  9,  0])

# %%
labels = np.unique(clusters)

for i in labels:
    plt.scatter(X_2D[clusters == i , 0] , X_2D[clusters == i , 1] , label = i)
plt.legend()
plt.show()

# %%
df = pd.DataFrame(X_2D)
df['cluster'] = clusters
df
# Out:
#            0         1  cluster
# 0   2.207161  0.006341        4
# 1   2.766999 -0.641633        4
# 2  -0.395013 -0.449778        8
# 3   0.837845 -0.522949        5
# 4   1.519967 -0.252935        5
# ..       ...       ...      ...
# 92  4.274943 -0.771865        4
# 93  2.909934 -1.765155       10
# 94 -0.994782 -1.163587        3
# 95 -1.080731  1.027106        9
# 96 -2.724284 -0.621588        0
#
# [97 rows x 3 columns]

# %%
for i in labels:
    plt.scatter(df[df['cluster'] == i][0] , df[df['cluster'] == i][1] , label = i)
plt.legend()
plt.show()

# %%
clusters = pd.Series(clusters).apply(lambda x: 0 if x == 1 else 1 if x == 2 else 2)

# %%
print(classification_report(y, clusters))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.00      0.00      0.00         5
#            2       0.18      0.79      0.29        19
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         5
#            5       0.00      0.00      0.00        14
#            7       0.00      0.00      0.00        11
#            8       0.00      0.00      0.00         5
#            9       0.00      0.00      0.00        11
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00         2
#
#     accuracy                           0.15        97
#    macro avg       0.02      0.07      0.03        97
# weighted avg       0.04      0.15      0.06        97
# ...

# %%
# Getting nearest point
from sklearn.metrics import pairwise_distances_argmin_min

X = X_df.drop('cluster', axis=1)
closest, _ = pairwise_distances_argmin_min(X.loc[[10]], X)
# here, this X.loc[[0]] would be representing "a new song"
closest
# Out:
# array([10], dtype=int64)
